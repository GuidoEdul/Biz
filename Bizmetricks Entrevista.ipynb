# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Desktop/datos_arts.csv")
df.head(5)
# Out:
#                    grupo                   depto        item  \
# 0  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025719
# 1  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025724
# 2  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025752
# 3  15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025907
# 4  15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025908
#
#                                             articulo       fecha  precio  \
# 0  1000025719 JABON EN BARRA BULL DOG GLICERINA 2...  19/08/2020      54
# 1  1000025724 JABON LIQUIDO PAR D.P. 800 CC NEVEX...  19/08/2020     136
# 2  1000025752 JABON LIQ NEVEX MATIC MULTIAC DIF D...  19/08/2020     410
# 3          1000025907 PANO DE PISO STANDARD 50X55 CM  19/08/2020      79
# 4                        1000025908 REJILLA 37X37CM.  19/08/2020      59
#
#    unidades  importe
# 0       7.0    378.0
# 1       1.0    136.0
# 2       1.0    410.0
# 3       1.0     79.0
# 4       1.0     59.0

# %%
df_agrupado = df.groupby("fecha").agg(
    cantidad_articulos=("articulo", "nunique"),
    total_importe=("importe", "sum")
)
df_agrupado
# Out:
#             cantidad_articulos  total_importe
# fecha
# 01/09/2020                 725      187805.51
# 01/10/2020                 714      217737.20
# 01/11/2020                 769      244827.88
# 02/09/2020                 777      236752.26
# 02/10/2020                 846      280201.06
# ...                        ...            ...
# 30/08/2020                 806      246807.36
# 30/09/2020                 683      188665.76
# 30/10/2020                 801      252455.86
# 31/08/2020                 664      182605.31
# 31/10/2020                 852      287103.04
#
# [84 rows x 2 columns]

# %%
df['SECTOR'] = df['grupo'].apply(lambda x: 'NO COMESTIBLES' if x in ['15 LIMPIEZA DEL HOGAR', '18 PERFUMERIA'] 
                                  else ('PERECEDEROS' if x in ['4 LACTEOS', '9 FIAMBRERIA'] 
                                        else x))
df
# Out:
#                        grupo                   depto        item  \
# 0      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025719
# 1      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025724
# 2      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025752
# 3      15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025907
# 4      15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025908
# ...                      ...                     ...         ...
# 63590  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000187363
# 63591          3 COMESTIBLES               GOLOSINAS  1000188100
# 63592          3 COMESTIBLES        ACEITES Y GRASAS  1000194151
# 63593          18 PERFUMERIA         CUIDADO CAPILAR  1000215423
# 63594          18 PERFUMERIA        CUIDADO CORPORAL  1000218721
#
#                                                 articulo       fecha  precio  \
# 0      1000025719 JABON EN BARRA BULL DOG GLICERINA 2...  19/08/2020      54
# ...

# %%
df[df["SECTOR"] == "PERECEDEROS"]
# Out:
#               grupo    depto        item  \
# 126       4 LACTEOS  YOGURES  1000047425
# 127       4 LACTEOS  YOGURES  1000047428
# 128       4 LACTEOS  YOGURES  1000047459
# 129       4 LACTEOS  YOGURES  1000047468
# 130       4 LACTEOS  YOGURES  1000047470
# ...             ...      ...         ...
# 63564  9 FIAMBRERIA   QUESOS  1000160807
# 63570     4 LACTEOS   QUESOS  1000166045
# 63578     4 LACTEOS   QUESOS  1000171614
# 63585     4 LACTEOS  YOGURES  1000181640
# 63586     4 LACTEOS  YOGURES  1000181641
#
#                                                 articulo       fecha  precio  \
# 126    1000047425 YOGUR FRUTILLA YOGURISIMO C/SORB 18...  19/08/2020      40
# 127        1000047428 ACTIVIA BEB CIRUELA SACHET 1.00 L.  19/08/2020      92
# 128    1000047459 YOGUR BEB YOGURISIMO GO FRUTILLA BO...  19/08/2020      35
# 129     1000047468 YOGUR VAINILLA DANONINO BOT 185.00 G.  19/08/2020      38
# 130    1000047470 YOGUR FRUTILLA DANONINO BOT 185.00 ML.  19/08/2020      38
# ...

# %%
df[df["SECTOR"] == "NO COMESTIBLES"]
# Out:
#                        grupo                   depto        item  \
# 0      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025719
# 1      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025724
# 2      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025752
# 3      15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025907
# 4      15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025908
# ...                      ...                     ...         ...
# 63582  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000178790
# 63583          18 PERFUMERIA         CUIDADO CAPILAR  1000178837
# 63590  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000187363
# 63593          18 PERFUMERIA         CUIDADO CAPILAR  1000215423
# 63594          18 PERFUMERIA        CUIDADO CORPORAL  1000218721
#
#                                                 articulo       fecha  precio  \
# 0      1000025719 JABON EN BARRA BULL DOG GLICERINA 2...  19/08/2020      54
# ...

# %%
sector_stats = df.groupby("SECTOR").agg({"precio": "mean", "importe": "sum"})


new_df = pd.DataFrame({
    "Sector": sector_stats.index.repeat(2),
    "Metric": ["Mean Price", "Total Sales"] * len(sector_stats),
    "Value": np.concatenate((sector_stats["precio"].values, sector_stats["importe"].values))
})


wide_df = new_df.pivot(index="Metric", columns="Sector", values="Value")







df.set_index('fecha')
print(df)


wide_df
# Out:
#                        grupo                   depto        item  \
# 0      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025719
# 1      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025724
# 2      15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000025752
# 3      15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025907
# 4      15 LIMPIEZA DEL HOGAR  CUIDADO DE SUPERFICIES  1000025908
# ...                      ...                     ...         ...
# 63590  15 LIMPIEZA DEL HOGAR      CUIDADO DE LA ROPA  1000187363
# 63591          3 COMESTIBLES               GOLOSINAS  1000188100
# 63592          3 COMESTIBLES        ACEITES Y GRASAS  1000194151
# 63593          18 PERFUMERIA         CUIDADO CAPILAR  1000215423
# 63594          18 PERFUMERIA        CUIDADO CORPORAL  1000218721
#
#                                                 articulo       fecha  precio  \
# 0      1000025719 JABON EN BARRA BULL DOG GLICERINA 2...  19/08/2020      54
# ...
